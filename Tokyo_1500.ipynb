# 4  27.09  28.83  29.16  29.67  29.66  30.04  29.66  29.77  29.72  29.74  ...
# 5  27.24  29.48  29.90  29.48  29.51  29.57  29.85  29.72  29.77  29.58  ...
# 6  27.61  29.36  29.89  29.44  29.94  29.95  30.28  30.03  30.13  30.20  ...
# 7  27.63  29.62  29.72  29.68  29.69  29.55  29.69  29.89  29.76  29.91  ...
# 8  27.70  29.57  29.99  29.95  30.15  30.09  30.09  29.96  30.07  29.99  ...
#
#     1300   1350   1400   1450   1500  FirstH  SecondH   First  Second   Third
# 1  29.50  29.40  29.42  28.60  25.78  441.58   438.07  293.43  296.11  290.11
# 2  29.58  29.46  29.48  28.61  26.78  441.38   439.28  293.02  296.12  291.52
# 3  29.41  29.60  29.12  28.49  27.76  441.03   439.88  292.42  296.37  292.12
# 4  29.93  29.04  29.68  29.27  29.16  442.08   442.93  293.34  296.79  294.88
# 5  30.35  30.35  30.23  29.76  28.74  444.17   451.31  294.10  300.19  301.19
# 6  29.98  30.22  29.96  29.72  27.82  447.48   448.37  296.83  300.67  298.35
# 7  30.56  30.67  30.49  30.56  29.64  446.03   457.44  295.14  302.86  305.47
# 8  30.92  31.00  30.81  30.15  29.25  447.71   456.55  297.56  301.06  305.64
#
# [8 rows x 35 columns]

# %%
Halves = [df['FirstH'],df['SecondH']]
plt.boxplot(Halves)

plt.xlabel("Halves of the race")
plt.ylabel("time in seconds")
plt.xticks([1, 2], ['750m', '1500m'] )
# naming the title of the plot
plt.title("Boxplot for the 1st(750m) and 2nd(750m) halves of the race (n=8)")
plt.show()

# %%
thirds = [df['First'],df['Second'],df['Third'],]
plt.boxplot(thirds)
plt.xlabel("Thirds of the race")
plt.ylabel("time in seconds")
 
# naming the title of the plot
plt.title("Boxplot for the 1st(500m), 2nd(500m) and 3rd(500m) of the race (n=8)")
plt.xticks([1, 2, 3], ['500m', '1000m', '1500m'] )
plt.show()

# %%
import pandas as pd
from scipy.stats import shapiro

# Assuming your DataFrame is named 'df'
# Iterate over each column and perform the Shapiro-Wilk test for normality
for column in df.columns:
    stat, p_value = shapiro(df[column])
    alpha = 0.05  # Significance level
    
    if p_value > alpha:
        print(f"The data in column '{column}' follows a normal distribution.")
    else:
        print(f"The data in column '{column}' does not follow a normal distribution.")
# Out:
# The data in column '50' follows a normal distribution.
# The data in column '100' follows a normal distribution.
# The data in column '150' follows a normal distribution.
# The data in column '200' follows a normal distribution.
# The data in column '250' follows a normal distribution.
# The data in column '300' follows a normal distribution.
# The data in column '350' follows a normal distribution.
# The data in column '400' follows a normal distribution.
# The data in column '450' follows a normal distribution.
# The data in column '500' follows a normal distribution.
# The data in column '550' follows a normal distribution.
# The data in column '600' follows a normal distribution.
# The data in column '650' follows a normal distribution.
# The data in column '700' follows a normal distribution.
# The data in column '750' follows a normal distribution.
# The data in column '800' follows a normal distribution.
# The data in column '850' follows a normal distribution.
# The data in column '900' follows a normal distribution.
# The data in column '950' follows a normal distribution.
# The data in column '1000' follows a normal distribution.
# The data in column '1050' follows a normal distribution.
# The data in column '1100' follows a normal distribution.
# The data in column '1150' follows a normal distribution.
# The data in column '1200' follows a normal distribution.
# The data in column '1250' follows a normal distribution.
# The data in column '1300' follows a normal distribution.
# The data in column '1350' follows a normal distribution.
# The data in column '1400' follows a normal distribution.
# The data in column '1450' follows a normal distribution.
# The data in column '1500' follows a normal distribution.
# The data in column 'FirstH' follows a normal distribution.
# The data in column 'SecondH' follows a normal distribution.
# The data in column 'First' follows a normal distribution.
# The data in column 'Second' follows a normal distribution.
# The data in column 'Third' follows a normal distribution.

# %%
import pandas as pd
from scipy.stats import f_oneway, ttest_ind

# Assuming your DataFrame is named 'df'
# Perform ANOVA to compare the means of the three columns
f_stat, p_value = f_oneway(df['First'], df['Second'], df['Third'])
if p_value < 0.05:
    print("There is a significant difference between the three columns (ANOVA)")

# Perform pairwise t-tests to compare each column with every other column
t_stat1_2, p_value1_2 = ttest_ind(df['First'], df['Second'])
t_stat1_3, p_value1_3 = ttest_ind(df['First'], df['Third'])
t_stat2_3, p_value2_3 = ttest_ind(df['Second'], df['Third'])

if p_value1_2 < 0.05:
    print("There is a significant difference between Column1 and Column2 (t-test)")
if p_value1_3 < 0.05:
    print("There is a significant difference between Column1 and Column3 (t-test)")
if p_value2_3 < 0.05:
    print("There is a significant difference between Column2 and Column3 (t-test)")

print("Column1 vs Column2 - p-value:", p_value1_2)
print("Column1 vs Column2 - t-statistic:", t_stat1_2)

print("Column1 vs Column3 - p-value:", p_value1_3)
print("Column1 vs Column3 - t-statistic:", t_stat1_3)

print("Column2 vs Column3 - p-value:", p_value2_3)
print("Column2 vs Column3 - t-statistic:", t_stat2_3)
# Out:
# There is a significant difference between Column1 and Column2 (t-test)
# Column1 vs Column2 - p-value: 0.002425705013586748
# Column1 vs Column2 - t-statistic: -3.689824876032802
# Column1 vs Column3 - p-value: 0.22222183508719182
# Column1 vs Column3 - t-statistic: -1.2774500741116206
# Column2 vs Column3 - p-value: 0.5790167348670412
# Column2 vs Column3 - t-statistic: 0.5680222132327631

# %%
df['250m']= df.iloc[:,:5].sum(axis =1)
df['500m']= df.iloc[:,5:10].sum(axis =1)
df['750m']= df.iloc[:,10:15].sum(axis =1)
df['1000m']= df.iloc[:,15:20].sum(axis =1)
df['1250m']= df.iloc[:,20:25].sum(axis =1)
df['1500m']= df.iloc[:,25:30].sum(axis =1)
df
# Out:
#       50    100    150    200    250    300    350    400    450    500  ...  \
# 1  27.45  29.38  29.25  29.64  29.40  29.83  29.65  29.73  29.54  29.56  ...
# 2  28.16  29.68  29.35  29.47  29.24  29.47  29.38  29.43  29.29  29.55  ...
# 3  27.38  29.18  29.31  29.39  29.48  29.56  29.46  29.69  29.35  29.62  ...
# 4  27.09  28.83  29.16  29.67  29.66  30.04  29.66  29.77  29.72  29.74  ...
# 5  27.24  29.48  29.90  29.48  29.51  29.57  29.85  29.72  29.77  29.58  ...
# 6  27.61  29.36  29.89  29.44  29.94  29.95  30.28  30.03  30.13  30.20  ...
# 7  27.63  29.62  29.72  29.68  29.69  29.55  29.69  29.89  29.76  29.91  ...
# 8  27.70  29.57  29.99  29.95  30.15  30.09  30.09  29.96  30.07  29.99  ...
#
#    SecondH   First  Second   Third    250m    500m    750m   1000m   1250m  \
# 1   438.07  293.43  296.11  290.11  145.12  148.31  148.15  147.96  147.41
# 2   439.28  293.02  296.12  291.52  145.90  147.12  148.36  147.76  147.61
# 3   439.88  292.42  296.37  292.12  144.74  147.68  148.61  147.76  147.74
# 4   442.93  293.34  296.79  294.88  144.41  148.93  148.74  148.05  147.80
# 5   451.31  294.10  300.19  301.19  145.61  148.49  150.07  150.12  151.76
# 6   448.37  296.83  300.67  298.35  146.24  150.59  150.65  150.02  150.65
# 7   457.44  295.14  302.86  305.47  146.34  148.80  150.89  151.97  153.55
# 8   456.55  297.56  301.06  305.64  147.36  150.20  150.15  150.91  153.51
#
#     1500m
# 1  142.70
# 2  143.91
# 3  144.38
# 4  147.08
# 5  149.43
# 6  147.70
# 7  151.92
# 8  152.13
#
# [8 rows x 41 columns]

# %%
f_stat, p_value = f_oneway(df['250m'], df['500m'], df['750m'],df['1000m'],df['1250m'],df['1500m'])
print("ANOVA - p-value:", p_value)
print("ANOVA - F-statistic:", f_stat)
# Out:
# ANOVA - p-value: 0.0017666852236056878
# ANOVA - F-statistic: 4.669676088800482

# %%
from itertools import combinations
columns = ['250m', '500m', '750m','1000m','1250m','1500m']
combinations_columns = list(combinations(columns, 2))
for column_pair in combinations_columns:
    col1, col2 = column_pair
    t_stat, p_value = ttest_ind(df[col1], df[col2])
    print(f"{col1} vs {col2} - p-value:", p_value)
    print(f"{col1} vs {col2} - t-statistic:", t_stat)
    
    if p_value < 0.05:
        print(f"Statistically significant difference detected between {col1} and {col2}.")
# Out:
# 250m vs 500m - p-value: 5.443874587160853e-05
# 250m vs 500m - t-statistic: -5.704352107438054
# Statistically significant difference detected between 250m and 500m.
# 250m vs 750m - p-value: 4.253428550395475e-06
# 250m vs 750m - t-statistic: -7.245497920008863
# Statistically significant difference detected between 250m and 750m.
# 250m vs 1000m - p-value: 0.00010296936334750846
# 250m vs 1000m - t-statistic: -5.347227183213534
# Statistically significant difference detected between 250m and 1000m.
# 250m vs 1250m - p-value: 0.0008204569574185717
# 250m vs 1250m - t-statistic: -4.24220520071626
# Statistically significant difference detected between 250m and 1250m.
# 250m vs 1500m - p-value: 0.21947957746155142
# 250m vs 1500m - t-statistic: -1.2854887027614696
# 500m vs 750m - p-value: 0.24608269912924088
# 500m vs 750m - t-statistic: -1.2106216720317724
# 500m vs 1000m - p-value: 0.4512676916184648
# 500m vs 1000m - t-statistic: -0.7749373516308055
# 500m vs 1250m - p-value: 0.25276051812739037
# 500m vs 1250m - t-statistic: -1.1928303244175555
# 500m vs 1500m - p-value: 0.3267139952521346
# 500m vs 1500m - t-statistic: 1.0163331319280633
# 750m vs 1000m - p-value: 0.851335914911955
# 750m vs 1000m - t-statistic: 0.19091134479496163
# 750m vs 1250m - p-value: 0.6005366317017211
# 750m vs 1250m - t-statistic: -0.5357547590471107
# 750m vs 1500m - p-value: 0.14606633640870811
# 750m vs 1500m - t-statistic: 1.5391233055723719
# 1000m vs 1250m - p-value: 0.5494043555025848
# 1000m vs 1250m - t-statistic: -0.6134689176904589
# 1000m vs 1500m - p-value: 0.1929962149931768
# 1000m vs 1500m - t-statistic: 1.3675856631368943
# 1250m vs 1500m - p-value: 0.1242983281940941
# 1250m vs 1500m - t-statistic: 1.6351292827801265

# %%
partial = [df['250m'],df['500m'],df['750m'],df['1000m'],df['1250m'],df['1500m']]
plt.boxplot(partial)
plt.xlabel("splits for every 250m")
plt.ylabel("time in seconds")
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
#plt.xticks(Labels)
plt.title("Boxplot for 250m splits (n=8)")
plt.xticks([1, 2, 3,4,5,6], ['250m', '500m', '750m','1000m','1250m','1500m'] )
plt.show()

# %%
new_df
# Out:
#          50       100       150       200       250       300       350  \
# 1  1.821494  1.701838  1.709402  1.686910  1.700680  1.676165  1.686341
# 2  1.775568  1.684636  1.703578  1.696641  1.709986  1.696641  1.701838
# 3  1.826150  1.713502  1.705902  1.701259  1.696065  1.691475  1.697217
# 4  1.845700  1.734305  1.714678  1.685204  1.685772  1.664447  1.685772
# 5  1.835536  1.696065  1.672241  1.696065  1.694341  1.690903  1.675042
# 6  1.810938  1.702997  1.672800  1.698370  1.670007  1.669449  1.651255
# 7  1.809627  1.688049  1.682369  1.684636  1.684069  1.692047  1.684069
# 8  1.805054  1.690903  1.667222  1.669449  1.658375  1.661682  1.661682
#
#         400       450       500  ...      1050      1100      1150      1200  \
# 1  1.681803  1.692620  1.691475  ...  1.691475  1.706485  1.689760  1.692620
# 2  1.698947  1.707067  1.692047  ...  1.700102  1.689760  1.691475  1.686910
# 3  1.684069  1.703578  1.688049  ...  1.688619  1.700102  1.681803  1.701838
# 4  1.679543  1.682369  1.681237  ...  1.703578  1.678979  1.701259  1.672241
# 5  1.682369  1.679543  1.690331  ...  1.650710  1.642576  1.649077  1.653439
# 6  1.665002  1.659476  1.655629  ...  1.663340  1.661682  1.663340  1.662234
# 7  1.672800  1.680108  1.671682  ...  1.635590  1.629195  1.621797  1.617599
# 8  1.668892  1.662787  1.667222  ...  1.647989  1.635590  1.626545  1.622850
#
#        1250      1300      1350      1400      1450      1500
# 1  1.699524  1.694915  1.700680  1.699524  1.748252  1.939488
# 2  1.700102  1.690331  1.697217  1.696065  1.747641  1.867065
# 3  1.688619  1.700102  1.689189  1.717033  1.755002  1.801153
# 4  1.701838  1.670565  1.721763  1.684636  1.708234  1.714678
# 5  1.640958  1.647446  1.647446  1.653986  1.680108  1.739736
# 6  1.646904  1.667779  1.654533  1.668892  1.682369  1.797268
# 7  1.636661  1.636126  1.630258  1.639882  1.636126  1.686910
# 8  1.610306  1.617076  1.612903  1.622850  1.658375  1.709402
#
# [8 rows x 30 columns]

# %%
first_row = new_df.iloc[0]
plt.figure(figsize=(10, 6))
plt.xticks(rotation=90)
# Plot the first row as a line graph
plt.plot(first_row)

# %%
rows = new_df.iloc[0]
rows1 = new_df.iloc[1]
rows2 = new_df.iloc[2]
plt.figure(figsize=(17, 6))
#plt.xticks(rotation=90)
#Plot the first row as a line graph
plt.plot(rows, color = '#FFD700')
plt.plot(rows1,color = '#AAAAAA')
plt.plot(rows2,color = '#8B7355')

plt.xlabel("50m splits")
plt.ylabel("speed in m/s")
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
plt.xticks(Labels)

plt.title("Medalist speed curves Tokyo 2021(n=3)")
plt.legend(["Gold", "Silver","Bronze"], loc ="upper left")
plt.show()

# %%
rows = new_df.iloc[0]
rows1 = new_df.iloc[1]
rows2 = new_df.iloc[2]
plt.figure(figsize=(17, 6))
#plt.xticks(rotation=90)
#Plot the first row as a line graph
plt.plot(rows[2:28], color = '#FFD700')
plt.plot(rows1[2:28],color = '#AAAAAA')
plt.plot(rows2[2:28],color = '#8B7355')

plt.xlabel("50m splits")
plt.ylabel("speed in m/s")
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
plt.xticks(Labels)

plt.title("Medalist speed curves Tokyo 2021(n=3)")
plt.legend(["Gold", "Silver","Bronze"], loc ="upper left")
plt.show()

# %%
rows = new_df.iloc[0]
rows1 = new_df.iloc[1]
rows2 = new_df.iloc[2]
rows3 = new_df.iloc[3]
rows4 = new_df.iloc[4]
rows5 = new_df.iloc[5]
rows6 = new_df.iloc[6]
rows7 = new_df.iloc[7]
plt.figure(figsize=(17, 6))
#plt.xticks(rotation=90)
#Plot the first row as a line graph
plt.plot(rows, color = '#000000', linestyle = 'dashed')
plt.plot(rows1,color = '#000000', linestyle = 'dashed')
plt.plot(rows2,color = '#000000', linestyle = 'dashed')
plt.plot(rows3)
plt.plot(rows4)
plt.plot(rows5)
plt.plot(rows6)
plt.plot(rows7)
plt.xlabel("50m splits")
plt.ylabel("speed in m/s")
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
plt.xticks(Labels)

plt.title("Medalist speed curves Tokyo 2021(n=3)")
plt.legend(["Gold", "Silver","Bronze", '4th', '5th', '6th', '7th', '8th'], loc ="upper left")
plt.show()

# %%
rows_to_plot = [ 1, 2,3,4,5,6,7,8]
plt.figure(figsize=(17, 6))
# Transpose the DataFrame and select the desired rows
rows = new_df.T[rows_to_plot];

# Plot the selected rows as lines
plt.plot(rows);
plt.xlabel("50m splits")
plt.ylabel("speed in m/s")
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
plt.xticks(Labels)
plt.legend(["1st", "2nd","3rd","4th","5th","6th","7th","8th"], loc ="upper left")
plt.title("Finalist speed curves Tokyo 2021(n=8)")
plt.show()

# %%
# Transpose the DataFrame
df_transposed = new_df.T

# Create a boxplot of the rows
#plt.figure(figsize=(10, 6))
plt.boxplot(df_transposed);
plt.xlabel("Finalists 1st to 8th")
plt.ylabel("speed in m/s")
#Labels = ['1st', '2nd', '3rd','4th','5th','6th','7th','8th'] 
# naming the title of the plot
plt.xticks([1, 2, 3,4,5,6,7,8], ['1st', '2nd', '3rd','4th','5th','6th','7th','8th'] )
# 400   1.668892  1.679273  1.689052  1.669511
# 450   1.662787  1.683598  1.699559  1.667665
# 500   1.667222  1.679830  1.692341  1.667342
# 550   1.652893  1.675130  1.688091  1.662191
# 600   1.673360  1.674969  1.683998  1.665955
# 650   1.668892  1.673092  1.685806  1.660400
# 700   1.668892  1.672161  1.683993  1.660350
# 750   1.661130  1.669620  1.685567  1.653701
# 800   1.654533  1.673270  1.684686  1.661875
# 850   1.658925  1.675766  1.695932  1.655636
# 900   1.655081  1.674401  1.691405  1.657427
# 950   1.658375  1.676287  1.697297  1.655314
# 1000  1.656178  1.673501  1.692960  1.654075
# 1050  1.647989  1.672912  1.697355  1.648512
# 1100  1.635590  1.668316  1.696226  1.640456
# 1150  1.626545  1.665906  1.694167  1.637694
# 1200  1.622850  1.663996  1.692890  1.635153
# 1250  1.610306  1.665937  1.699234  1.632698
# 1300  1.617076  1.665811  1.693489  1.638181
# 1350  1.612903  1.669593  1.705165  1.634084
# 1400  1.622850  1.673148  1.703077  1.643272
# 1450  1.658375  1.702417  1.744126  1.660782
# 1500  1.709402  1.782745  1.863593  1.702040

# %%
plt.figure(figsize=(17, 10));
plt.plot(rows);
plt.xlabel("50m splits")
plt.ylabel("speed in m/s")
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
plt.xticks(Labels)
#plt.figure(figsize=(17, 10))

# naming the title of the plot
plt.xticks(Labels)
#plt.plot(rows)
plt.plot(rows['mean'],linestyle = 'dashed', color='black');
plt.plot(rows['std +'],linestyle = 'dashed', color='black');
plt.plot(rows['std -'],linestyle = 'dashed', color='black');

# %%
diff = rows.diff(axis=1).iloc[:, 1:8]  # Calculate differences column-wise, excluding the first column
plt.figure(figsize=(17, 10));
# Create a scatter plot for each data point
for col in diff.columns:
    plt.plot(diff.index, diff[col], marker='+', label=col, linestyle='')

# Add labels and title to the plot
#plt.plot(diff.iloc[:, 0],linestyle = 'dashed', color='black');
plt.xlabel('Data Point')
plt.ylabel('Difference')
plt.title('Difference between Columns')
Labels = ['250', '500', '750','1000','1250','1500 '] 
# naming the title of the plot
plt.xticks(Labels)
# Add a legend to identify each column
plt.legend()

# Display the plot
plt.show()

# %%
diff['1'] = 0
diff
# Out:
#              2         3         4         5         6         7         8  1
# 50   -0.045925  0.050582  0.019549 -0.010164 -0.024598 -0.001311 -0.004573  0
# 100  -0.017202  0.028866  0.020802 -0.038239  0.006932 -0.014949  0.002854  0
# 150  -0.005824  0.002325  0.008775 -0.042437  0.000559  0.009569 -0.015146  0
# 200   0.009731  0.004618 -0.016055  0.010861  0.002304 -0.013733 -0.015187  0
# 250   0.009306 -0.013921 -0.010293  0.008569 -0.024334  0.014062 -0.025694  0
# 300   0.020476 -0.005166 -0.027028  0.026456 -0.021454  0.022598 -0.030366  0
# 350   0.015497 -0.004621 -0.011444 -0.010730 -0.023787  0.032814 -0.022387  0
# 400   0.017144 -0.014878 -0.004526  0.002826 -0.017367  0.007799 -0.003908  0
# 450   0.014447 -0.003490 -0.021209 -0.002826 -0.020068  0.020632 -0.017321  0
# 500   0.000572 -0.003999 -0.006811  0.009094 -0.034702  0.016053 -0.004459  0
# 550   0.000000 -0.013641 -0.003937  0.000000 -0.015566  0.013885 -0.020468  0
# 600  -0.002273 -0.001701 -0.009015 -0.001680 -0.005018 -0.009397  0.015535  0
# 650  -0.000569 -0.006793  0.010210 -0.029714 -0.001101 -0.001648  0.012166  0
# 700  -0.002267  0.004541 -0.009620 -0.012288 -0.005526 -0.007675  0.017091  0
# 750  -0.006802  0.003394  0.005117 -0.030794 -0.004932 -0.008156  0.016393  0
# 800   0.000000 -0.001134  0.000567 -0.016279  0.003901 -0.013298 -0.003292  0
# 850   0.006284  0.001722  0.005765 -0.026760 -0.019934 -0.011950  0.016889  0
# 900   0.000573  0.004596 -0.017673 -0.016203 -0.000553 -0.011532  0.003826  0
# 950   0.003447 -0.008022  0.013799 -0.044043  0.013866 -0.033434  0.019568  0
# 1000  0.001146  0.002872 -0.018776 -0.013396  0.008347 -0.036650  0.020587  0
# 1050  0.008627 -0.011483  0.014959 -0.052868  0.012630 -0.027750  0.012399  0
# 1100 -0.016725  0.010342 -0.021123 -0.036404  0.019106 -0.032486  0.006395  0
# 1150  0.001715 -0.009672  0.019456 -0.052182  0.014263 -0.041543  0.004748  0
# 1200 -0.005711  0.014928 -0.029597 -0.018802  0.008795 -0.044635  0.005250  0
# 1250  0.000578 -0.011483  0.013219 -0.060880  0.005946 -0.010243 -0.026355  0
# 1300 -0.004584  0.009771 -0.029537 -0.023118  0.020332 -0.031653 -0.019049  0
# 1350 -0.003464 -0.008027  0.032574 -0.074317  0.007087 -0.024276 -0.017354  0
# 1400 -0.003459  0.020968 -0.032397 -0.030650  0.014906 -0.029010 -0.017032  0
# 1450 -0.000611  0.007361 -0.046768 -0.028126  0.002261 -0.046243  0.022249  0
# 1500 -0.072423 -0.065912 -0.086475  0.025058  0.057533 -0.110359  0.022492  0

# %%
plt.boxplot(diff)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ff4d187580>,
#   <matplotlib.lines.Line2D at 0x1ff4d187850>,
#   <matplotlib.lines.Line2D at 0x1ff4d195970>,
#   <matplotlib.lines.Line2D at 0x1ff4d195c40>,
#   <matplotlib.lines.Line2D at 0x1ff4d1a1d60>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ae070>,
#   <matplotlib.lines.Line2D at 0x1ff4d1bb1c0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1bb490>,
#   <matplotlib.lines.Line2D at 0x1ff4d1c85b0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1c8880>,
#   <matplotlib.lines.Line2D at 0x1ff4d1d49a0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1d4c70>,
#   <matplotlib.lines.Line2D at 0x1ff4d1e0d90>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ee0a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ff4d187b20>,
#   <matplotlib.lines.Line2D at 0x1ff4d187df0>,
#   <matplotlib.lines.Line2D at 0x1ff4d195f10>,
#   <matplotlib.lines.Line2D at 0x1ff4d1a1220>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ae340>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ae640>,
#   <matplotlib.lines.Line2D at 0x1ff4d1bb760>,
#   <matplotlib.lines.Line2D at 0x1ff4d1bba30>,
#   <matplotlib.lines.Line2D at 0x1ff4d1c8b50>,
#   <matplotlib.lines.Line2D at 0x1ff4d1c8e20>,
#   <matplotlib.lines.Line2D at 0x1ff4d1d4f40>,
#   <matplotlib.lines.Line2D at 0x1ff4d1e0250>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ee370>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ee640>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ff4d1872b0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1956a0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1a1a90>,
#   <matplotlib.lines.Line2D at 0x1ff4d1aeeb0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1c82e0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1d46d0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1e0ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ff4d195100>,
#   <matplotlib.lines.Line2D at 0x1ff4d1a14f0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ae910>,
#   <matplotlib.lines.Line2D at 0x1ff4d1bbd00>,
#   <matplotlib.lines.Line2D at 0x1ff4d1d4130>,
#   <matplotlib.lines.Line2D at 0x1ff4d1e0520>,
#   <matplotlib.lines.Line2D at 0x1ff4d1ee910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ff4d1953d0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1a17c0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1aebe0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1bbfd0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1d4400>,
#   <matplotlib.lines.Line2D at 0x1ff4d1e07f0>,
#   <matplotlib.lines.Line2D at 0x1ff4d1eebe0>],
#  'means': []}

# %%
rows_to_compare = new_df.iloc[0:9, :]  # Rows 1 to 9
rows_to_compare
# Out:
#          50       100       150       200       250       300       350  \
# 1  1.821494  1.701838  1.709402  1.686910  1.700680  1.676165  1.686341
# 2  1.775568  1.684636  1.703578  1.696641  1.709986  1.696641  1.701838
# 3  1.826150  1.713502  1.705902  1.701259  1.696065  1.691475  1.697217
# 4  1.845700  1.734305  1.714678  1.685204  1.685772  1.664447  1.685772
# 5  1.835536  1.696065  1.672241  1.696065  1.694341  1.690903  1.675042
# 6  1.810938  1.702997  1.672800  1.698370  1.670007  1.669449  1.651255
# 7  1.809627  1.688049  1.682369  1.684636  1.684069  1.692047  1.684069
# 8  1.805054  1.690903  1.667222  1.669449  1.658375  1.661682  1.661682
#
#         400       450       500  ...      1050      1100      1150      1200  \
# 1  1.681803  1.692620  1.691475  ...  1.691475  1.706485  1.689760  1.692620
# 2  1.698947  1.707067  1.692047  ...  1.700102  1.689760  1.691475  1.686910
# 3  1.684069  1.703578  1.688049  ...  1.688619  1.700102  1.681803  1.701838
# 4  1.679543  1.682369  1.681237  ...  1.703578  1.678979  1.701259  1.672241
# 5  1.682369  1.679543  1.690331  ...  1.650710  1.642576  1.649077  1.653439
# 6  1.665002  1.659476  1.655629  ...  1.663340  1.661682  1.663340  1.662234
# 7  1.672800  1.680108  1.671682  ...  1.635590  1.629195  1.621797  1.617599
# 8  1.668892  1.662787  1.667222  ...  1.647989  1.635590  1.626545  1.622850
#
#        1250      1300      1350      1400      1450      1500
# 1  1.699524  1.694915  1.700680  1.699524  1.748252  1.939488
# 2  1.700102  1.690331  1.697217  1.696065  1.747641  1.867065
# 3  1.688619  1.700102  1.689189  1.717033  1.755002  1.801153
# 4  1.701838  1.670565  1.721763  1.684636  1.708234  1.714678
# 5  1.640958  1.647446  1.647446  1.653986  1.680108  1.739736
# 6  1.646904  1.667779  1.654533  1.668892  1.682369  1.797268
# 7  1.636661  1.636126  1.630258  1.639882  1.636126  1.686910
# 8  1.610306  1.617076  1.612903  1.622850  1.658375  1.709402
#
# [8 rows x 30 columns]

# %%
import pandas as pd
from scipy.stats import kruskal

# Assuming your DataFrame is named 'df'

# Select the specific rows for comparison
rows_to_compare = new_df.iloc[0:9, :]  # Rows 1 to 9

# Perform the Kruskal-Wallis test
statistic, p_value = kruskal(*rows_to_compare.values)

# Print the Kruskal-Wallis test results
print("Kruskal-Wallis Test Results:")
print("Statistic:", statistic)
print("P-value:", p_value)

# Check for significant differences
alpha = 0.05
significant_rows = []
for i in range(rows_to_compare.shape[0]):
    group1 = rows_to_compare.iloc[i, :]
    for j in range(i+1, rows_to_compare.shape[0]):
        group2 = rows_to_compare.iloc[j, :]
        statistic, p_value = kruskal(group1, group2)
        if p_value < alpha:
            significant_rows.append((i+1, j+1, p_value))

# Print the rows with significant differences
if significant_rows:
    print("Rows with Significant Differences:")
    for row in significant_rows:
        print(f"Rows {row[0]} and {row[1]}, p-value = {row[2]:.4f}")
else:
    print("No Significant Differences Found.")
# Out:
# Kruskal-Wallis Test Results:
# Statistic: 111.77726148926321
# P-value: 3.927503316455371e-21
# Rows with Significant Differences:
# Rows 1 and 5, p-value = 0.0000
# Rows 1 and 6, p-value = 0.0000
# Rows 1 and 7, p-value = 0.0000
# Rows 1 and 8, p-value = 0.0000
# Rows 2 and 5, p-value = 0.0000
# Rows 2 and 6, p-value = 0.0000
# Rows 2 and 7, p-value = 0.0000
# Rows 2 and 8, p-value = 0.0000
# Rows 3 and 5, p-value = 0.0000
# Rows 3 and 6, p-value = 0.0000
# Rows 3 and 7, p-value = 0.0000
# Rows 3 and 8, p-value = 0.0000
# Rows 4 and 5, p-value = 0.0003
# Rows 4 and 6, p-value = 0.0000
# Rows 4 and 7, p-value = 0.0000
# Rows 4 and 8, p-value = 0.0000
# Rows 5 and 7, p-value = 0.0286
# Rows 5 and 8, p-value = 0.0308
# Rows 6 and 8, p-value = 0.0320

# %%
rows = new_df.iloc[:8]  # Select the first three rows
plt.figure(figsize=(10, 6))
plt.xticks(rotation=90)
# Plot the three rows as lines
rows.T.plot()

# Set the title, x-axis label, and y-axis label
plt.title('Three Lines from DataFrame')
plt.xlabel('Column')
plt.ylabel('Value')

# Display the legend
#plt.legend()

# Show the plot
# Out:
# Text(0, 0.5, 'Value')
